# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import linear_model

# %%
df=pd.read_csv("D:/Python Librarys/datasets/multilinearregression.csv")
df
# Out:
#   alan;odasayisi;binayasi;fiyat
# 0               180;5;10;510000
# 1               225;4;18;508000
# 2                260;3;2;548000
# 3               320;6;10;650000
# 4                335;4;9;628000
# 5               345;5;14;632000
# 6                355;3;0;680000
# 7               400;4;10;725000

# %%
reg=linear_model.LinearRegression()

df = df['alan;odasayisi;binayasi;fiyat'].str.split(';', expand=True)
df.columns = ['alan', 'odasayisi', 'binayasi', 'fiyat']

# Convert columns to numeric types
df = df.astype({'alan': 'int', 'odasayisi': 'int', 'binayasi': 'int', 'fiyat': 'int'})

# Fit the regression model
reg.fit(df[['alan', 'odasayisi', 'binayasi']], df['fiyat'])
# Out:
# LinearRegression()

# %%
reg.predict([[230,6,0],[500,1,1],[1000,2,0],[1500,3,1],[2000,4,1]])
# Out:
# c:\Kurulumlar\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([ 586097.7833456 ,  784151.61702118, 1311151.4523391 ,
#        1832937.91905708, 2357331.07007503])

# %%
reg.coef_   # b1,b2,b3
# Out:
# array([ 1018.99865454, 14893.82374984, -2606.68429997])

# %%
reg.intercept_# a
# Out:
# 262365.15030320536

# %%
# y = a + b1*x1 + b2*x2 + b3*x3
# y = a + b1*alan + b2*odasayisi + b3*binayasi

a=reg.intercept_
b1=reg.coef_[0]
b2=reg.coef_[1]
b3=reg.coef_[2]

x1=230
x2=6
x3=3
y=a+b1*x1+b2*x2+b3*x3
print("Tahmin edilen fiyat: ",y)


# Plotting the data
plt.scatter(df['alan'], df['fiyat'], color='blue', label='Alan')
plt.scatter(df['odasayisi'], df['fiyat'], color='red', label='Oda Sayısı')
plt.scatter(df['binayasi'], df['fiyat'], color='green', label='Binayaşı')
plt.xlabel('Özellikler')
plt.ylabel('Fiyat')
plt.title('Çoklu Doğrusal Regresyon')
plt.legend()
plt.show()
# Out:
# Tahmin edilen fiyat:  578277.7304456834
